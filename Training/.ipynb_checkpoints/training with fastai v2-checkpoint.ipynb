# %%
# !pip install -Uqq fastbook

# %%
import fastbook
fastbook.setup_book()
# Out:
# c:\program files\python37\lib\site-packages\fastbook\__init__.py:18: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
??fastbook.setup_book

# %%
from fastbook import *
from fastai.vision.all import *

# %%
mask = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
path = Path("../data")

# %%
fns = get_image_files(path)
fns
# Out:
# (#1376) [Path('../data/without_mask/0.jpg'),Path('../data/without_mask/1.jpg'),Path('../data/without_mask/10.jpg'),Path('../data/without_mask/100.jpg'),Path('../data/without_mask/101.jpg'),Path('../data/without_mask/102.jpg'),Path('../data/without_mask/104.jpg'),Path('../data/without_mask/105.jpg'),Path('../data/without_mask/106.jpg'),Path('../data/without_mask/107.jpg')...]

# %%
dls = mask.dataloaders(path,num_workers=0)

# %%
dls.valid.show_batch(max_n=10, nrows=2)

# %%
mask = mask.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = mask.dataloaders(path,num_workers=0)

# %%
learn = cnn_learner(dls, resnet18, metrics=[error_rate,accuracy])
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.388851</td>
#       <td>0.038072</td>
#       <td>0.010909</td>
#       <td>0.989091</td>
#       <td>02:26</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.051941</td>
#       <td>0.004769</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>03:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.032078</td>
#       <td>0.000474</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>02:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.024440</td>
#       <td>0.000580</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>02:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.019820</td>
#       <td>0.001497</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>02:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn.export("model3.pkl")

# %%
learn.dls.vocab
